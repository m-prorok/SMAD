# %%
import pandas as pd
yeast_data = pd.read_excel("datasets\yeast.xlsx")

# %%
X = yeast_data[['Column2', 'Column3', 'Column4', 'Column5', 'Column6', 'Column7', 'Column8', 'Column9']]
y = yeast_data['Column10']

print(X.shape)
print(y.shape)
# Out:
# (1484, 8)
# (1484,)

# %%
y.value_counts()
# Out:
# CYT    463
# NUC    429
# MIT    244
# ME3    163
# ME2     51
# ME1     44
# EXC     35
# VAC     30
# POX     20
# ERL      5
# Name: Column10, dtype: int64

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
yt = le.fit_transform(y)
yt
# Out:
# array([6, 6, 6, ..., 4, 7, 0])

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

skf = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)

from sklearn.neighbors import KNeighborsClassifier

mylist = [3,6,10,15,20,25,30,40,50,60]
for k in mylist:
    model = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(model, X, yt, scoring='accuracy', cv=skf, n_jobs=-1)
    print("k= ", k, scores, scores.mean())
# Out:
# k=  3 [0.56228956 0.57912458 0.51515152 0.57575758 0.5472973 ] 0.5559241059241059
# k=  6 [0.56228956 0.57575758 0.53872054 0.56902357 0.58783784] 0.5667258167258167
# k=  10 [0.55555556 0.58585859 0.52861953 0.5959596  0.5777027 ] 0.5687391937391937
# k=  15 [0.55555556 0.59259259 0.55218855 0.59259259 0.61148649] 0.5808831558831559
# k=  20 [0.57912458 0.5993266  0.52861953 0.5993266  0.60472973] 0.5822254072254073
# k=  25 [0.56902357 0.58922559 0.53535354 0.62289562 0.59459459] 0.5822185822185822
# k=  30 [0.55218855 0.5993266  0.52188552 0.61616162 0.60810811] 0.5795340795340795
# k=  40 [0.55555556 0.55555556 0.51851852 0.60942761 0.61148649] 0.5701087451087451
# k=  50 [0.55892256 0.56565657 0.52525253 0.61616162 0.59797297] 0.5727932477932478
# k=  60 [0.54545455 0.54882155 0.52525253 0.6026936  0.59797297] 0.5640390390390391

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import Normalizer

scaler = Normalizer()
scaled_features = scaler.fit_transform(X)
#model = KNeighborsClassifier(n_neighbors=20, metric=cosine_similarity)
X = cosine_similarity(scaled_features,scaled_features)

model = KNeighborsClassifier(n_neighbors=20, metric='precomputed')
scores = cross_val_score(model, scaled_features, yt, scoring='accuracy', cv=skf, n_jobs=-1)
print(scores, scores.mean())
# Out:
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\magda\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py", line 431, in _process_worker
#     r = call_item()
#   File "C:\Users\magda\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py", line 285, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "C:\Users\magda\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\magda\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\magda\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
# ...
